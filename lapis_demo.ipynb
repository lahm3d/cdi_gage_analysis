# %%
from lapis import lapis, noaa_dav, gps_time
# import leafmap
import leafmap.leafmap as leafmap  # for ipyleaflet only

# %% [markdown]
# ### Inputs: coordinates (converted to circles), polygon features (shapefiles, gpkg, geojson etc., -- Only single part), or bounding boxes

# %%
locations_dict = [
    {
        'name': 'gage id01650500',
        'data_type': 'coords',
        'value': (-77.0293611, 39.06552778), #longitude, latitude
        'buffer': 50, # in meters -- default value is 50 meters unless specified 
    },
    {
        'name': 'gage id 01651000',
        'data_type': 'coords',
        'value': (-76.96513889, 38.95255556), #longitude, latitude
        'buffer': 50, # in meters -- default value is 50 meters unless specified 
    },
    {
        'name': 'washington dc',
        'data_type': 'file',
        'value': 'demo/district_of_columbia_boundary.geojson'
    },
    {
        'name': 'augusta county, va',
        'data_type': 'bbox',
        'value': [-79.53330839559011, 37.88158664008918, -78.74939547673364, 38.477678774587105]
    }
]

# %% [markdown]
# ### Find all lidar collections that intersect provided locations (using USIAEI)
#
# USIAEI lists all lidar collections, but sometimes paths to EPT (Entwine Point Tiles) files are not included. Another source of these EPT files is NOAA's Digital Access Viewer (DAV). First step is to webscrape all of NOAA's collection names and corresponding EPT files if any and cross walk the records from USIAEI and NOAA.

# %%
find_lidar = lapis.SearchLidarInventory(locations_dict)
locations, collections = find_lidar.get_lidar_collections()

# %% [markdown]
# ### Result(s)

# %%
locations[['name', 'geometry']]
# Out:
#                  name                                           geometry
# 0     gage id01650500  POLYGON ((-77.02879 39.06544, -77.02880 39.065...
# 1    gage id 01651000  POLYGON ((-76.96457 38.95247, -76.96458 38.952...
# 2       washington dc  POLYGON ((-77.00244 38.96567, -77.00150 38.964...
# 3  augusta county, va  POLYGON ((-79.53331 37.88159, -78.74940 37.881...

# %%
collections.head(3)
# Out:
#                                             geometry  OBJECTID     ID  \
# 0  POLYGON ((-77.16494 39.30900, -77.16678 39.312...       161  28493
# 1  POLYGON ((-77.45889 39.21983, -77.47362 39.208...       876  24506
# 2  POLYGON ((-77.11908 39.27012, -77.12978 39.271...      1556  42214
#
#                                                Title    DataType    Status  \
# 0  2018 MNCPPC Lidar: Montgomery and Prince Georg...  Lidar-Topo  Complete
# 1                       2008 Montgomery County Lidar  Lidar-Topo  Complete
# 2  2021 MNCPPC Lidar: Montgomery and Prince Georg...  Lidar-Topo  Complete
#
#                                                Links   pointspacing  \
# 0  {"links":[{"link":"https:\/\/lidar.geodata.md....   0.7 m (spec)
# 1  {"links":[{"link":"http:\/\/www6.montgomerycou...   Not Provided
# 2                                               None  0.35 m (spec)
#
#                                     verticalaccuracy horizontalaccuracy  ...  \
# 0  {"vertAccuracy":[{"VertDescription":"4.6 cm RM...              0.5 m  ...
# 1  {"vertAccuracy":[{"VertDescription":"15 cm RMS...                1 m  ...
# 2  {"vertAccuracy":[{"VertDescription":"10 cm (sp...              0.5 m  ...
#
#   horizontaldatum  restrictions leafOnOff  \
# 0      NAD83 HARN        Public      None
# 1           NAD83         Other      None
# 2      NAD83 HARN        Public      None
#
#                              AlternateTitle  \
# 0                                      None
# 1                                      None
# 2  USGS: MD_2020MontgomeryPrinceGeorges_C22
#
#                                            notes RecordOwner  ContractSpec  \
# 0  Plans are to submit to USGS after acceptance.        USGS  USGS LBS 1.2
# 1                                                       USGS       Unknown
# 2                                           None        USGS       Unknown
#
#     Shape_Length    Shape_Area             name
# 0  441920.168052  4.317304e+09  gage id01650500
# 1  221628.863882  2.181791e+09  gage id01650500
# 2  426673.478813  4.243600e+09  gage id01650500
#
# [3 rows x 30 columns]

# %%
print(f"total collections: {collections.shape[0]}\n")
# Out:
# total collections: 28

# %% [markdown]
# ### Cross-reference NOAA DAV - by web scraping

# %%
noaa_dav_gdf = noaa_dav.scrape_digital_coast_repo()

# %% [markdown]
# ### Parse lidar collections and extract EPT (if any)

# %%
collections = lapis.ProcessLidarCollections(collections, locations, noaa_dav_gdf).execute()
# Out:
# Curl failure: Timeout was reached

# %% [markdown]
# Notable columns in this dataframe:
# - `Title`: Lidar collection title
# - `collectionyear`: from USIEI -- year of lidar collection
# - `ept_usiaei`: EPT file path from USIAEI if present
# - `noaa_id`: If a USIEI collection is present in NOAA DAV repo then the unique will be present
# - `ID #`: same as `noaa_id` for cross-walk
# - `ept_noaa`: EPT file paths pulled from NOAA DAV
# - `ept`: reconciled EPT urls -- this cross-references USIAEI and NOAA DAV and used to retrieve point clouds
# - `ept_crs`: CRS for EPT files which is needed for on-the-fly transformation
# - `ept_gdf`: GeoDataframe of the original location feature reprojected to the native CRS of the EPT file

# %%
collections[['name', 'Title', 'collectionyear', 'collectiondate', 'meets3dep', 'Status']]
# Out:
#                   name                                              Title  \
# 0      gage id01650500  2018 MNCPPC Lidar: Montgomery and Prince Georg...
# 1      gage id01650500                       2008 Montgomery County Lidar
# 2      gage id01650500  2021 MNCPPC Lidar: Montgomery and Prince Georg...
# 3      gage id01650500  2013 Montgomery County Maryland National Park ...
# 4     gage id 01651000  2018 MNCPPC Lidar: Montgomery and Prince Georg...
# 5     gage id 01651000  2014 USGS Hurricane Sandy Supplemental for Nat...
# 6     gage id 01651000  2021 MNCPPC Lidar: Montgomery and Prince Georg...
# 7        washington dc  2018 MNCPPC Lidar: Montgomery and Prince Georg...
# 8        washington dc  2022 USGS Northern Virginia (Fairfax, Loudoun,...
# 9        washington dc                       2008 Montgomery County Lidar
# 10       washington dc  2014 USGS Hurricane Sandy Supplemental for Nat...
# 11       washington dc                           2004 Washington DC Lidar
# 12       washington dc                2020 District of Columbia QL2 Lidar
# 13       washington dc  2021 MNCPPC Lidar: Montgomery and Prince Georg...
# 14       washington dc             2012 FEMA Lidar: Region 3 (MD, VA, WV)
# 15       washington dc       2022 District of Columbia QL2 Redacted Lidar
# 16       washington dc  2013 Montgomery County Maryland National Park ...
# 17       washington dc                2017 - 2018 Washington DC QL2 Lidar
# 18       washington dc           2015 District of Columbia-OCTO QL1 Lidar
# 19       washington dc                           2003 Washington DC Lidar
# 20       washington dc                       2018 Fairfax County VA Lidar
# 21       washington dc                2022 District of Columbia QL2 Lidar
# 22  augusta county, va                    2016 VA FEMA R3 Southwest Lidar
# 23  augusta county, va                  2016 Chesapeake Bay, VA QL2 Lidar
# 24  augusta county, va             2017 VA Chesapeake Bay Watershed Lidar
# 25  augusta county, va                  2020 Northern Shenandoah VA Lidar
# 26  augusta county, va                           2011 NRCS Virginia Lidar
# 27       washington dc                    2019 Potomac River MD Topobathy
#
#     collectionyear                                     collectiondate  \
# 0             2018                               Feb 8 - Sep 27, 2018
# 1             2008  Feb 17, Mar 3, 5, 6, 11, 20, 24, 26, 29,  Apr ...
# 2             2021                                               2021
# 3             2014                     Dec 27 - 28, 2013, Jan 7, 2014
# 4             2018                               Feb 8 - Sep 27, 2018
# 5             2014                              Apr 10 - Dec 20, 2014
# 6             2021                                               2021
# 7             2018                               Feb 8 - Sep 27, 2018
# 8             2022                                          Dec. 2022
# 9             2008  Feb 17, Mar 3, 5, 6, 11, 20, 24, 26, 29,  Apr ...
# 10            2014                              Apr 10 - Dec 20, 2014
# 11            2004                                               2004
# 12            2020                                  Jun 26 - 30, 2020
# 13            2021                                               2021
# 14            2012                              Jan 29 - Apr 26, 2012
# 15            2022                                   Jan 24, 26, 2022
# 16            2014                     Dec 27 - 28, 2013, Jan 7, 2014
# 17            2018                              Leaf-off  2017 - 2018
# 18            2015                                   Apr 1 - 24, 2015
# 19            2003                                               2003
# 20            2018                                   Dec 6 - 26, 2018
# 21            2022                                   Jan 24, 26, 2022
# 22            2016  Nov 3, 2016 - Apr 13, 2017 (VA); Mar 23 - Apr ...
# 23            2016                            Nov 15 - Dec 16, 2015
# 24            2017                       Apr 14, 2017 - May 25, 2018
# 25            2020                                               2021
# 26            2011                                    Apr 7 - 30 2011
# 27            2019                                               2020
#
#                        meets3dep       Status
# 0   Pending Contribution to 3DEP     Complete
# 1                             No     Complete
# 2   Pending Contribution to 3DEP     Complete
# 3                             No     Complete
# 4   Pending Contribution to 3DEP     Complete
# 5                            Yes     Complete
# 6   Pending Contribution to 3DEP     Complete
# 7   Pending Contribution to 3DEP     Complete
# 8               Expected to meet  In Progress
# 9                             No     Complete
# 10                           Yes     Complete
# 11                            No     Complete
# 12  Pending Contribution to 3DEP     Complete
# 13  Pending Contribution to 3DEP     Complete
# 14                            No     Complete
# 15                       Unknown     Complete
# 16                            No     Complete
# 17  Pending Contribution to 3DEP     Complete
# 18  Pending Contribution to 3DEP     Complete
# 19                            No     Complete
# 20                           Yes     Complete
# 21                       Unknown     Complete
# 22                           Yes     Complete
# 23                           Yes     Complete
# 24                           Yes     Complete
# 25                           Yes     Complete
# 26                            No     Complete
# 27                            No     Complete

# %% [markdown]
# EPT files and/or lidar point clouds are stored in their native projection system. In the collections, geodataframe. The `ept_gdf` column stores the location geodataframe transformed to the native EPT CRS.

# %%
# collections[['Title', 'collectionyear', 'meets3dep', 'Status', 'ept_usiaei', 'ept_noaa', 'ept', 'ept_crs', 'ept_gdf']]

# %% [markdown]
# # Map and explore lidar collections

# %%
# convert gdfs to geojson
locations_geojson = leafmap.gdf_to_geojson(locations, epsg=4326)
collections_geojson = leafmap.gdf_to_geojson(collections, epsg=4326)

# %%
m = leafmap.Map()
style = {'fillOpacity': 0.5}
m.add_geojson(locations_geojson, layer_name='locations', color='blue', style=style)
m.add_geojson(collections_geojson, layer_name='collections', style=style)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## Enter the index number to extract `ept` url path and `ept_bbox` bounding box to retrieve the lidar point clouds using PDAL

# %%
index = 0
collection = collections.iloc[[index]]
collection[['Title', 'name']]

# %%
count, arrays, metadata, demo_las = lapis.fetch_lidar(collection, geometry_method='polygon', write=True)

# %%
array = arrays[0] # 0 is for data and 1 is for datatype + column names

print('no.of points / count: ', count)
print('no. arrays: ', len(arrays))
# print('metadata: ', metadata)

# %%
timestamps = gps_time.LidarTimestamps(arrays[0]).get_timestamps()

# %%
print(timestamps, collection.collectiondate)

# %% [markdown]
# # Lidar visualization (experimental -- may not work)

# %%
# las = leafmap.read_lidar(demo_las)

# %%
# leafmap.view_lidar(demo_las, cmap='terrain', backend='pyvista')

# %%
# leafmap.view_lidar(demo_las, cmap='terrain', backend='ipygany')

# %%
# leafmap.view_lidar(demo_las, cmap='terrain', backend='panel')
